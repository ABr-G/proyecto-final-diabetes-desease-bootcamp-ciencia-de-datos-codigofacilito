# %% [markdown]
# # Diabetic Retinopathy

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("C:/Users/Abril/Downloads/diabetes.csv")

# %%
df.head
# Out:
# <bound method NDFrame.head of      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]>

# %%
df.shape
# Out:
# (768, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
corr = df.corr()
plt.figure(figsize = (10,8))
sns.heatmap(corr,annot = True, cmap = "BuPu")
plt.show()

# %%
sns.scatterplot(data = df, x = "Glucose", y="BloodPressure", hue="Outcome")
plt.show()

# %%
sns.lineplot(data = df, x= "Age", y = "Pregnancies", color = "red")
plt.show()
# Out:
# C:\Users\Abril\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Abril\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.scatterplot(data = df, x = "Age", y = "SkinThickness", hue = "Outcome")
# Out:
# <Axes: xlabel='Age', ylabel='SkinThickness'>

# %%
sns.displot(data = df, x = "Glucose", color = "pink", kde = True)
plt.show()
# Out:
# C:\Users\Abril\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.displot(data = df, x="BloodPressure", color = "Blue", kde = True)
plt.show()
# Out:
# C:\Users\Abril\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.displot(data = df, x="Age", color = "purple", kde = True)
plt.show()
# Out:
# C:\Users\Abril\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.countplot(y="Outcome", data = df, palette = "Set1")
plt.show()

# %%
sns.scatterplot(data = df, x = "Age", y = "BMI", hue = "Outcome", palette = "inferno")
# Out:
# <Axes: xlabel='Age', ylabel='BMI'>

# %%
X = df.drop(columns = "Outcome", axis = 1)
Y = df["Outcome"]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.2, random_state = 42)

# %% [markdown]
# # Desicion Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
dt.fit(X_train, Y_train)
y_pred = dt.predict(X_test)

# %%
from sklearn.metrics import f1_score, recall_score, precision_score, roc_auc_score, accuracy_score

f1 = f1_score(Y_test, y_pred)
recall = recall_score(Y_test, y_pred)
precision = precision_score(Y_test, y_pred)
roc_auc = roc_auc_score(Y_test, y_pred)
accuracy = accuracy_score(Y_test, y_pred)

print("F1 Score:", f1)
print("Recall:", recall)
print("Precision:", precision)
print("ROC AUC Score:", roc_auc)
print("Accuracy Score:", accuracy)
# Out:
# F1 Score: 0.6607142857142858
# Recall: 0.6727272727272727
# Precision: 0.6491228070175439
# ROC AUC Score: 0.7353535353535354
# Accuracy Score: 0.7532467532467533

# %%
import scikitplot as skplt
y_probas = dt.predict_proba(X_test)
skplt.metrics.plot_roc(y_test, y_probas)
plt.show()

# revisar !! Instalar -->scikitplot<-- en Anaconda.
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 import scikitplot as skplt
#       2 y_probas = dt.predict_proba(X_test)
#       3 skplt.metrics.plot_roc(y_test, y_probas)
#
# ModuleNotFoundError: No module named 'scikitplot'

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(X_train, Y_train)
pred1 = rf.predict(X_test)

# %%
f10 = f1_score(Y_test, pred1)
recall0 = recall_score(Y_test, pred1)
precision0 = precision_score(Y_test, pred1)
roc_auc0 = roc_auc_score(Y_test, pred1)
accuracy0 = accuracy_score(Y_test, pred1)

print("F1 Score:", f10)
print("Recall:", recall0)
print("Precision:", precision0)
print("ROC AUC Score:", roc_auc0)
print("Accuracy Score:", accuracy0)
# Out:
# F1 Score: 0.6481481481481481
# Recall: 0.6363636363636364
# Precision: 0.660377358490566
# ROC AUC Score: 0.7272727272727272
# Accuracy Score: 0.7532467532467533

# %%
y_proba = rf.predict_proba(X_test)
skplt.metrics.plot_roc(Y_test,Y_proba)
plt.show()

# error! Instalar skp en Anaconda para visuzliar el grafico
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 2
#       1 y_proba = rf.predict_proba(X_test)
# ----> 2 skplt.metrics.plot_roc(Y_test,Y_proba)
#       3 plt.show()
#
# NameError: name 'skplt' is not defined

# %% [markdown]
# # LGBM Classifier

# %%
from lightgbm import LGBMClassifier
lgb = LGBMClassifier()
lgb.fit(X_train, Y_train)
pred2 = lbg.predict(X_test)

# error ! instalar lightgbm para ejecutar el c[odigo]
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 from lightgbm import LGBMClassifier
#       2 lgb = LGBMClassifier()
#       3 lgb.fit(X_train, Y_train)
#
# ModuleNotFoundError: No module named 'lightgbm'

# %%
f11 = f1_score(Y_test, pred2)
recall1 = recall_score(Y_test, pred2)
precision1 = precision_score(Y_test, pred2)
roc_auc1 = roc_auc_score(Y_test, pred2)
accuracy1 = accuracy_score(Y_test, pred2)

print("F1 Score:", f11)
print("Recall:", recall1)
print("Precision:", precision1)
print("ROC AUC Score:", roc_auc1)
print("Accuracy Score:", accuracy1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 f11 = f1_score(Y_test, pred2)
#       2 recall1 = recall_score(Y_test, pred2)
#       3 precision1 = precision_score(Y_test, pred2)
#
# NameError: name 'pred2' is not defined

# %%
y_pro = rf.predict_proba(X_test)
skplt.metrics.plot_roc(y_test, y_pro)
plt.show()

# error! instalar skplt para visualizar el grafico
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 2
#       1 y_pro = rf.predict_proba(X_test)
# ----> 2 skplt.metrics.plot_roc(y_test, y_pro)
#       3 plt.show()
#
# NameError: name 'skplt' is not defined

# %%
import numpy as np
plt.figure(figsize=(15,10))
dt_metrics = [f1, recall, precision, roc_auc, accuracy]
rf_metrics = [f10, recall0, precision0, roc_auc0, accuracy0]
lgb_metrics = [f11, recall1, precision1, roc_auc1, accuracy1]
metrics_labels = ['F1 score', 'Recall', 'Precision', 'ROC AUC Score', 'Accuracy Score']
bar_width = 0.25

r1 = np.arange(len(dt_metrics))
r2 = [x + bar_width for x in r1]
r3 = [x + bar_width for x in r2]

plt.bar(r1, dt_metrics, color='b', width=bar_width, edgecolor='green', label='Decision Tree Classifier')
plt.bar(r2, rf_metrics, color='g', width=bar_width, edgecolor='green', label='Random Forest Classifier')
plt.bar(r3, lgb_metrics, color='r', width=bar_width, edgecolor='green', label='LGBM Classifier')

plt.xlabel('Metrics', fontweight='bold')
plt.xticks([r + bar_width for r in range(len(dt_metrics))], metrics_labels)

plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 5
#       3 dt_metrics = [f1, recall, precision, roc_auc, accuracy]
#       4 rf_metrics = [f10, recall0, precision0, roc_auc0, accuracy0]
# ----> 5 lgb_metrics = [f11, recall1, precision1, roc_auc1, accuracy1]
#       6 metrics_labels = ['F1 score', 'Recall', 'Precision', 'ROC AUC Score', 'Accuracy Score']
#       7 bar_width = 0.25
#
# NameError: name 'f11' is not defined

# %%
y_probas_dt = dt.predict_proba(X_test)
y_probas_rf = rf.predict_proba(X_test)
y_probas_lgb = lgb.predict_proba(X_test)


plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
plt.close()
skplt.metric.plot_roc(y_test, y_probas_dt)
plt.title('Decision Tree Classifier')
plt.show()

plt.subplot(1, 3, 2)
plt.close()
skplt.metric.plot_roc(y_test, y_probas_rf)
plt.title('Random Forest Classifier')
plt.show()

plt.subplot(1, 3, 3)
plt.close()
skplt.metric.plot_roc(y_test, y_probas_lgb)
plt.title('LGBM Classifier')
plt.show()

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 2
#       1 y_probas_dt = dt.predict_proba(X_test)
# ----> 2 y_probas_rf = rf.predict_proba(X_test)
#       3 y_probas_lgb = lgb.predict_proba(X_test)
#       6 plt.figure(figsize=(15, 5))
#
# NameError: name 'rf' is not defined
